# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

shp_file_name = 'food_access/tl_2010_53_tract00/tl_2010_53_tract00.shp'
csv_file_name = 'food_access/food_access.csv'

# %%
census = gpd.read_file(shp_file_name)
food_access = pd.read_csv(csv_file_name)
food_access['CensusTract'] = food_access['CensusTract'].astype(int)
result = census.merge(food_access, left_on='CTIDFP00', right_on='CensusTract', how='left')
# Out:
# /Users/binganchen/opt/anaconda3/envs/cse163/lib/python3.8/site-packages/geopandas/array.py:85: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   aout[:] = out

# %%
state_data = result
state_data.plot(color='#EEEEEE')
wa_data = state_data[state_data['State'] == 'WA']
wa_data.plot(column='POP2010', legend=True)
plt.title('Washington Census Tract Populations')
plt.savefig('population_map.png')
# Out:
# /Users/binganchen/opt/anaconda3/envs/cse163/lib/python3.8/site-packages/geopandas/plotting.py:38: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in geom:
# /Users/binganchen/opt/anaconda3/envs/cse163/lib/python3.8/site-packages/descartes/patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
# /Users/binganchen/opt/anaconda3/envs/cse163/lib/python3.8/site-packages/descartes/patch.py:64: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   [asarray(r)[:, :2] for r in t.interiors])
# /Users/binganchen/opt/anaconda3/envs/cse163/lib/python3.8/site-packages/geopandas/plotting.py:38: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in geom:
# /Users/binganchen/opt/anaconda3/envs/cse163/lib/python3.8/site-packages/descartes/patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([
# /Users/binganchen/opt/anaconda3/envs/cse163/lib/python3.8/site-packages/descartes/patch.py:64: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   [asarray(r)[:, :2] for r in t.interiors])
